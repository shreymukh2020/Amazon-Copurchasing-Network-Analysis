# %% [markdown]
# # Amazon Book Recommendation system for product co-purchasing network metadata

# %% [markdown]
# The dataset is available on the Stanford Network Analysis Project (SNAP) website from the following link: http://snap.stanford.edu/data/amazon-meta.html

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Graph Analytics Project')

# %% [markdown]
# ### Import required libraries

# %%
# !pip install stemming
# Out:
# Requirement already satisfied: stemming in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
import string
import pandas as pd
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from stemming.porter2 import stem
import networkx
import numpy as np
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import matplotlib.pylab as plt
from IPython.display import Image
from community import community_louvain
from collections import Counter
from itertools import chain
#pyo.init_notebook_mode()
import plotly.io as pio
pio.renderers.default = 'colab'
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Open the file to read Amazon Product Metadata
df = open ('amazon-meta.txt', 'r', encoding='utf-8', errors= 'ignore')

# %% [markdown]
# ### Description of the dataset
# The data was collected in summer 2006 by crawling the Amazon website. The dataset provides information about product metadata and review metadata on 548,552 different products. For each product in the dataset, the following informations are available:
# - Title
# - Salesrank
# - List of similar products (that get co-purchased with the current product)
# - Detailed product categorization
# - Product reviews: time, customer, rating, number of votes, number of people that found the review helpful
#
# The data format is:
# - ID: Product number (number 0, …, 548551)
# - ASIN: Amazon Standard Identification Number is a 10-character alphanumeric unique identifier assigned by Amazon.com for product identification
# - Title: Name/title of the product
# - Group: The product group can be Book, DVD, Video or Music
# - Sales rank: The Amazon sales rank represents how a product is selling in comparison to other products in its primary category. The lower the rank, the better a product is selling
# - Similar: ASINs of co-purchased products, such as people who buy X also buy Y
# - Categories: Location in product category hierarchy to which the product belongs (separated by |, category id in [...] )
# - Reviews: Product review information such as the total number of reviews, average rating and the individual customer review information including time, user id, rating, total number of votes on the review, total number of helpfulness votes which means how many people found the review to be helpful

# %% [markdown]
# ### Dataset Preprocessing

# %%
# Initialize a nested product dictionary that will hold cleaned up amazon product data.
amazonProducts= {}

# %% [markdown]
# Data Description:
#
# - ID, ASIN, Title, Sales rank, Total reviews, and Average rating are the same as described above.
# - All the categories associated with the ASIN are concatenated, and then the are subject to Text Preprocessing steps: lowercase, stemming, remove digit/punctuation, remove stop words, retain only unique words.
# - The copurchased ASINs in the “similar” field are filtered down to only those ASINs that have metadata associated with it.

# %%
# Read the data from the Amazon file and fill the amazonProducts nested dictionary
(Id, ASIN, Title, Categories, Group, Copurchased, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff) = ("", "", "", "", "", "", 0, 0, 0.0, 0, 0.0)

for line in df:
    line = line.strip()
    if(line.startswith("Id")): # a product block started
        Id = line[3:].strip()
    elif(line.startswith("ASIN")):
        ASIN = line[5:].strip()
    elif(line.startswith("title")):
        Title = line[6:].strip()
        Title = ' '.join(Title.split())
    elif(line.startswith("group")):
        Group = line[6:].strip()
    elif(line.startswith("salesrank")):
        SalesRank = line[10:].strip()
    elif(line.startswith("similar")):
        ls = line.split()
        Copurchased = ' '.join([c for c in ls[2:]])
    elif(line.startswith("categories")):
        ls = line.split()
        Categories = ' '.join((df.readline()).lower() for i in range(int(ls[1].strip())))
        Categories = re.compile('[%s]' % re.escape(string.digits+string.punctuation)).sub(' ',Categories)
        Categories = ' '.join(set(Categories.split())-set(stopwords.words("english")))
        Categories = ' '.join(stem(word) for word in Categories.split())
    elif(line.startswith("reviews")):
        ls = line.split()
        TotalReviews = ls[2].strip()
        AvgRating = ls[7].strip() # a product block ended
    elif (line==""): # write out fields to amazonProducts dictionary
        try:
            MetaData = {}
            if (ASIN != ""):
                amazonProducts[ASIN] = MetaData
            MetaData['Id'] = Id
            MetaData['Title'] = Title
            MetaData['Categories'] = ' '.join(set(Categories.split()))
            MetaData['Group'] = Group
            MetaData['Copurchased'] = Copurchased
            MetaData['SalesRank'] = int(SalesRank)
            MetaData['TotalReviews'] = int(TotalReviews)
            MetaData['AvgRating'] = float(AvgRating)
            MetaData['DegreeCentrality'] = DegreeCentrality
            MetaData['ClusteringCoeff'] = ClusteringCoeff
        except NameError:
            continue
        (Id, ASIN, Title, Categories, Group, Copurchased, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff) = ("", "", "", "", "", "", 0, 0, 0.0, 0, 0.0)
df.close
# Out:
# <function TextIOWrapper.close()>

# %% [markdown]
# ## Focus only on the book category of products. Filter Amazon products dictionary down to only Group=Book and write it to amazonBooks dictionary.

# %%
#create book specific dictionary exclusively for books
amazonBooks = {}
for asin,metadata in amazonProducts.items():
    if (metadata['Group']=='Book'):
        amazonBooks[asin]=amazonProducts[asin]

#remove any copurchased items from copurchase list. If we don't have metadata associated with it
for asin, metadata in amazonBooks.items():
    amazonBooks[asin]['Copurchased']= ' '.join([cp for cp in metadata['Copurchased'].split() if cp in amazonBooks.keys()])

# %%
amazonBooks
# Out:
# {'0827229534': {'Id': '1',
#   'Title': 'Patterns of Preaching: A Sermon Sampler',
#   'Categories': 'religion sermon book spiritu christian subject preach clergi',
#   'Group': 'Book',
#   'Copurchased': '0804215715 156101074X 0687023955 0687074231 082721619X',
#   'SalesRank': 396585,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0738700797': {'Id': '2',
#   'Title': 'Candlemas: Feast of Flames',
#   'Categories': 'religion witchcraft book spiritu subject base earth wicca',
#   'Group': 'Book',
#   'Copurchased': '0738700827 1567184960 1567182836 0738700525 0738700940',
#   'SalesRank': 168596,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486287785': {'Id': '3',
#   'Title': 'World War II Allied Fighter Planes Trading Cards',
#   'Categories': 'home book subject garden craft hobbi general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1270652,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0842328327': {'Id': '4',
#   'Title': 'Life Application Bible Commentary: 1 and 2 Timothy and Titus',
#   'Categories': 'discipleship live life sacr religion text studi book bibl guid christian subject applic general new refer translat spiritu commentari histori testament',
#   'Group': 'Book',
#   'Copurchased': '0842328130 0842330313 0842328610 0842328572',
#   'SalesRank': 631289,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1577943082': {'Id': '5',
#   'Title': 'Prayers That Avail Much for Business: Executive',
#   'Categories': 'religion live prayerbook busi worship book spiritu christian subject devot',
#   'Group': 'Book',
#   'Copurchased': '157794349X 0892749504 1577941829 0892749563',
#   'SalesRank': 455160,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486220125': {'Id': '6',
#   'Title': 'How the Other Half Lives: Studies Among the Tenements of New York',
#   'Categories': 'essay book social scienc urban sociolog camera state subject categori art photographi general america nonfict jewish unit photo histori',
#   'Group': 'Book',
#   'Copurchased': '0486401960 0452283612 0486229076 0714840343',
#   'SalesRank': 188784,
#   'TotalReviews': 17,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0231118597': {'Id': '8',
#   'Title': 'Losing Matt Shepard',
#   'Categories': 'crime polit nonfict book gay criminolog subject u lesbian general crimin',
#   'Group': 'Book',
#   'Copurchased': '0375727191 080148605X 1560232579 0300089023',
#   'SalesRank': 277409,
#   'TotalReviews': 15,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1859677800': {'Id': '9',
#   'Title': 'Making Bread: The Taste of Traditional Home-Baking',
#   'Categories': 'wine bake bread book subject food cook',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 949166,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375709363': {'Id': '10',
#   'Title': 'The Edward Said Reader',
#   'Categories': 'polit critic anthropolog nonfict book social subject literatur scienc theori cultur fiction histori general',
#   'Group': 'Book',
#   'Copurchased': '039474067X 0679730672 0679750541 1400030668 0896086704',
#   'SalesRank': 220379,
#   'TotalReviews': 6,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0871318237': {'Id': '11',
#   'Title': 'Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life',
#   'Categories': 'profession bodi medicin technic health altern book specialti subject holist store jp medic mind unknown general',
#   'Group': 'Book',
#   'Copurchased': '0060984341 0553577514 1571742972 0962741817',
#   'SalesRank': 412962,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1590770218': {'Id': '12',
#   'Title': 'Fantastic Food with Splenda : 160 Great Recipes for Meals Low in Sugar, Carbohydrates, Fat, and Calories',
#   'Categories': 'nutrit carbohydr condit diabet herb bodi book special wine carb health sugar condiment subject low cook general ingredi free weight loss food diet fat mind spice',
#   'Group': 'Book',
#   'Copurchased': '0871319640',
#   'SalesRank': 24741,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0313230269': {'Id': '13',
#   'Title': 'Clockwork Worlds : Mechanized Environments in SF (Contributions to the Study of Science Fiction and Fantasy)',
#   'Categories': 'fantasi critic book scienc literatur subject theori fiction histori general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 2895088,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1559362022': {'Id': '15',
#   'Title': 'Wake Up and Smell the Coffee',
#   'Categories': 'theater author state eric book z subject literatur bogosian perform drama b art unit fiction photographi general',
#   'Group': 'Book',
#   'Copurchased': '1559360968 1559361247 1559360828 1559361018 0743214552',
#   'SalesRank': 518927,
#   'TotalReviews': 8,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0195110382': {'Id': '16',
#   'Title': 'War at Sea: A Naval History of World War II',
#   'Categories': 'general war ii book militari subject histori world naval',
#   'Group': 'Book',
#   'Copurchased': '1585741485 0140246967 1557504288',
#   'SalesRank': 631564,
#   'TotalReviews': 10,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0849311012': {'Id': '17',
#   'Title': 'Telecommunications Cost Management',
#   'Categories': 'system industri manag manufactur busi microprocessor book econom telecommun offic home internet subject store invest oper general hardwar com comput amazon leadership engin design',
#   'Group': 'Book',
#   'Copurchased': '1580531784 1578200326',
#   'SalesRank': 570183,
#   'TotalReviews': 3,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '078510870X': {'Id': '19',
#   'Title': 'Ultimate Marvel Team-Up',
#   'Categories': 'graphic marvel children fantasi horror book publish superhero scienc novel literatur subject comic mysteri fiction teen',
#   'Group': 'Book',
#   'Copurchased': '078511078X',
#   'SalesRank': 612475,
#   'TotalReviews': 8,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '3895780812': {'Id': '20',
#   'Title': 'Computed Tomography : Fundamentals, System Technology, Image Quality, Applications',
#   'Categories': 'profession technic medicin comput specialti book intern internet subject medic radiolog general',
#   'Group': 'Book',
#   'Copurchased': '0865778973 0071343547 0721662854 0721681735 0819444251',
#   'SalesRank': 179448,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393049388': {'Id': '23',
#   'Title': 'Strange Fire: A Novel',
#   'Categories': 'book contemporari subject literatur thriller mysteri fiction general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1277867,
#   'TotalReviews': 3,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553525476': {'Id': '24',
#   'Title': 'The Casebook of Sherlock Holmes, Volume 2 (Casebook of Sherlock Holmes)',
#   'Categories': 'format conan broadcast book radio detect sir author sherlock doyl z subject thriller mysteri british holm entertain general tape show arthur',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1545277,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0939165252': {'Id': '25',
#   'Title': 'Jailed for Freedom: American Women Win the Vote',
#   'Categories': 'nonfict studi book subject govern women histori elect',
#   'Group': 'Book',
#   'Copurchased': '059500055X 0674106539',
#   'SalesRank': 326756,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1590930509': {'Id': '26',
#   'Title': 'Chicken Little',
#   'Categories': 'children stori tale myth pictur book age subject fairi literatur folk general',
#   'Group': 'Book',
#   'Copurchased': '0439078172 0899192254 0688070450 0899193498 1577683684',
#   'SalesRank': 242571,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0231096704': {'Id': '27',
#   'Title': 'The Columbia Anthology of Gay Literature',
#   'Categories': 'group classic nonfict studi book social gay literatur special subject scienc lesbian fiction general',
#   'Group': 'Book',
#   'Copurchased': '0140172483 0375707409 0520078748',
#   'SalesRank': 1119683,
#   'TotalReviews': 2,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1893732290': {'Id': '28',
#   'Title': "God Knows Marriage Isn't Always Easy: 12 Ways to Add Zest (God Knows)",
#   'Categories': 'religion live marriag book relationship christian spiritu subject faith',
#   'Group': 'Book',
#   'Copurchased': '1893732398 0609805797',
#   'SalesRank': 745886,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0781718791': {'Id': '29',
#   'Title': 'Advanced Pediatric Clinical Assessment: Skills and Procedures',
#   'Categories': 'medicin profession technic pediatr nurs specialti book diagnosi subject assess medic neonat general',
#   'Group': 'Book',
#   'Copurchased': '0071360387 0323016774 0781735114 0721680178',
#   'SalesRank': 677416,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0471150274': {'Id': '30',
#   'Title': 'Solving Statics Problems with MathCAD',
#   'Categories': 'aerospac civil book specialti subject store jp engin unknown general mechan advanc',
#   'Group': 'Book',
#   'Copurchased': '013061081X 1852331666 0070121893',
#   'SalesRank': 227883,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0895872218': {'Id': '31',
#   'Title': 'Backroad Buffets & Country Cafes: A Southern Guide to Meat-And-Threes & Down-Home Dining',
#   'Categories': 'dine industri profess region busi book intern offic travel wine hospit home state subject store u categori invest cook general com south amazon lodg food tourism unit',
#   'Group': 'Book',
#   'Copurchased': '1892514656 0767908090',
#   'SalesRank': 507787,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0761116982': {'Id': '32',
#   'Title': 'Staff Meals from Chanterelle',
#   'Categories': 'wine profession gastronomi region book intern subject food histori u cook atlant middl general',
#   'Group': 'Book',
#   'Copurchased': '0393020436 0767903609 0312290233 0471287857',
#   'SalesRank': 150657,
#   'TotalReviews': 11,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0439240751': {'Id': '33',
#   'Title': 'Double Jeopardy (T*Witches, 6)',
#   'Categories': 'fantasi children twin witch book scienc literatur jp unknown teen horror subject store mysteri fiction specialti issu adventur magic seri',
#   'Group': 'Book',
#   'Copurchased': '0439240727 0439240719 0439240700 0061062499',
#   'SalesRank': 97166,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0618111212': {'Id': '35',
#   'Title': 'Burnt Toast on Davenport Street',
#   'Categories': 'fantasi children horror humor anim dog pictur book age scienc literatur subject mysteri magic fiction general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 317983,
#   'TotalReviews': 5,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1898630038': {'Id': '36',
#   'Title': 'Uists & Barra (Pevensey Island guides)',
#   'Categories': 'britain com great europ amazon book scotland subject store categori travel general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1406353,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0787950599': {'Id': '38',
#   'Title': 'Resolving Conflicts At Work : A Complete Guide for Everyone on the Job',
#   'Categories': 'psycholog life resourc industri secret manag profess bodi busi book guid biographi offic counsel home success health internet primer subject store organiz invest personnel human general com comput amazon occup digit cultur mind',
#   'Group': 'Book',
#   'Copurchased': '0874777518 0071364315 014028852X 1402200552 078795019X',
#   'SalesRank': 644042,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312199406': {'Id': '39',
#   'Title': 'Night of Many Dreams : A Novel',
#   'Categories': 'popular book club specialti contemporari subject literatur store fiction general',
#   'Group': 'Book',
#   'Copurchased': '0312267568 0312316089 0312099436 0312144075 0446674346',
#   'SalesRank': 57186,
#   'TotalReviews': 22,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1573221740': {'Id': '40',
#   'Title': 'Renovations: A Father and Son Rebuild a House and Rediscover Each Other',
#   'Categories': 'home famili memoir relationship book remodel renov child subject adult biographi parent garden design general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 678019,
#   'TotalReviews': 8,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0130132543': {'Id': '41',
#   'Title': 'Workbook: The Long-Term Care Nursing Assistant',
#   'Categories': 'profession technic medicin refer physician nurs book hospic patient care subject medic',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 2014896,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486268780': {'Id': '43',
#   'Title': 'Selected Poems (Dover Thrift Editions)',
#   'Categories': 'th centuri walt general author state poetri classic book w z subject singl literatur whitman unit fiction world',
#   'Group': 'Book',
#   'Copurchased': '0486275507 0486401588 0486272737 0486285537 0486264661',
#   'SalesRank': 260300,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1861007418': {'Id': '45',
#   'Title': 'Beginning ASP.NET Databases using C#',
#   'Categories': 'page program tool religion book server web activ languag christian internet subject general databas comput spiritu eschatolog theolog c',
#   'Group': 'Book',
#   'Copurchased': '1861006098 1861007329 1861007191 1861007868',
#   'SalesRank': 48408,
#   'TotalReviews': 4,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0826449379': {'Id': '46',
#   'Title': "Alternative Worlds in Fantasy Fiction (Contemporary Classics of Children's Literature)",
#   'Categories': 'fantasi critic classic famili book scienc literatur subject histori theori guid parent read fiction teen general',
#   'Group': 'Book',
#   'Copurchased': '0889652015 0380651939 0141301163 0440418321 0689845332',
#   'SalesRank': 1115213,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0590568833': {'Id': '47',
#   'Title': 'How to Kill a Monster (Goosebumps)',
#   'Categories': 'fantasi children r spine book scienc literatur monster horror author l z age subject mysteri fiction general obsess chill illustr stine',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 654748,
#   'TotalReviews': 10,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0439420717': {'Id': '48',
#   'Title': 'Scooby-doo Mysteries #24 (Scooby-Doo Mysteries)',
#   'Categories': 'fantasi children del spine book cultur j scienc literatur detect horror author espionag scoobi z subject mysteri fiction popular humor doo chill jame seri',
#   'Group': 'Book',
#   'Copurchased': '0439284899 0439284880 043924238X 0439284864 0439188814',
#   'SalesRank': 529184,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0687054532': {'Id': '51',
#   'Title': 'Out on the Edge: A Wake-Up Call for Church Leaders on the Edge of the Media Reformation',
#   'Categories': 'pentecost religion general spiritu book christian subject histori church protestant clergi ministri',
#   'Group': 'Book',
#   'Copurchased': '0687052130 0687069157 0764422979 0687045479 0687083737',
#   'SalesRank': 505266,
#   'TotalReviews': 7,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0875420532': {'Id': '52',
#   'Title': "Secrets of Gypsy Love Magick (Llewellyn's New Age Series)",
#   'Categories': 'love bodi religion occult romanc book social scienc sociolog folklor health subject general nonfict spiritu relationship mytholog magic mind',
#   'Group': 'Book',
#   'Copurchased': '156718099X 1567180973 1578632617',
#   'SalesRank': 409481,
#   'TotalReviews': 6,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0944708498': {'Id': '53',
#   'Title': 'Baby Boomer Retirement: 65 Simple Ways to Protect Your Future',
#   'Categories': 'com home busi famili amazon book age retir financ subject store financi invest parent plan offic person general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 566643,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0613100093': {'Id': '54',
#   'Title': 'Betsy & Tacy Go over the Big Hill (Betsy and Tacy Books)',
#   'Categories': 'children betsi classic fiction situat action book age social subject literatur adventur place taci friendship seri peopl general',
#   'Group': 'Book',
#   'Copurchased': '0064400964 0064401103 0064401111 0064405478 0064405451',
#   'SalesRank': 629348,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0486275035': {'Id': '55',
#   'Title': 'Goldilocks and the Three Bears : Full-Color Picture Book (Dover Little Activity Books)',
#   'Categories': 'children humor book age subject literatur general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1269904,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1550416243': {'Id': '56',
#   'Title': 'Three Bricks Shy of a Load: A Collection of True Stories About Ordinary People Doing Really Dumb Stuff!',
#   'Categories': 'humor book subject entertain essay general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 2167012,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0398068917': {'Id': '57',
#   'Title': 'Investigating Computer Crime: A Primer for Security Managers',
#   'Categories': 'com hacker comput home secur busi project amazon book internet subject offic store digit cultur general manag',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1501773,
#   'TotalReviews': 1,
#   'AvgRating': 1.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '087842461X': {'Id': '58',
#   'Title': 'Raptors of the Rockies: Biology of the Birds of Prey and Species Accounts of the Raptors of the Rockies',
#   'Categories': 'mountain field natur outdoor region book jp guid bird unknown birdwatch state subject store general rocki refer specialti unit',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1091842,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393971694': {'Id': '60',
#   'Title': 'Renaissance Music: Music in Western Europe, 1400-1600 (Norton Introduction to Music History)',
#   'Categories': 'new use critic europ book specialti subject histori appreci store music textbook art entertain human general',
#   'Group': 'Book',
#   'Copurchased': '0393090906 0195122321 0136081924 039395272X',
#   'SalesRank': 373682,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1550373080': {'Id': '61',
#   'Title': 'Hermanos (Hablemos)',
#   'Categories': 'format children life juvenil infantil año libro peopl book bebe sibl spanish subject place en nonfict multilingu famili español',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 890775,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0026879077': {'Id': '62',
#   'Title': 'Scoring High on the Stanford Achievement Test',
#   'Categories': 'educ children refer school nonfict book subject',
#   'Group': 'Book',
#   'Copurchased': '0026879018 1930288034 1930288018 1576906779 193028800X',
#   'SalesRank': 1157369,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0966723821': {'Id': '63',
#   'Title': 'Historia De Cancer De Una Dietista : Informacion & Inspiracion para la Recuperacion & Curacion Sobreviviente de tres canceres',
#   'Categories': 'format nutrit biografía condit academ español diseas profession bodi altern book intern special biographi medicin health memoir subject medic general oncolog topic en weight loss memoria diet cancer disord mind libro',
#   'Group': 'Book',
#   'Copurchased': '0972252207 0963837281 0471346683 0812930665',
#   'SalesRank': 613909,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0689846088': {'Id': '64',
#   'Title': 'A Charlie Brown Christmas',
#   'Categories': 'children festiv pictur christma book age subject place holiday fiction peopl general',
#   'Group': 'Book',
#   'Copurchased': '068984607X 0689850271 0689848218 0689848226 0689851634',
#   'SalesRank': 423424,
#   'TotalReviews': 6,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0273651870': {'Id': '65',
#   'Title': 'Economics for Business',
#   'Categories': 'com home busi amazon book subject store invest offic general',
#   'Group': 'Book',
#   'Copurchased': '0131000691 053438367X',
#   'SalesRank': 963890,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0393037622': {'Id': '66',
#   'Title': 'Blood and Guts: A Short History of Medicine',
#   'Categories': 'medicin topic book scienc special subject mathemat histori general',
#   'Group': 'Book',
#   'Copurchased': '0192802674 0393319806 157912156X',
#   'SalesRank': 408761,
#   'TotalReviews': 4,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1571515429': {'Id': '67',
#   'Title': 'Picture Me With My Friend Jesus: Girl Version (Picture Me)',
#   'Categories': 'religion children jesus book christian age subject biographi fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 784192,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0810114275': {'Id': '68',
#   'Title': 'Experiencing and the Creation of Meaning: A Philosophical and Psychological Approach to the Subjective (Studies in Phenomenology and Existential Philosophy)',
#   'Categories': 'nonfict phenomenolog modern book subject movement philosophi epistemolog general',
#   'Group': 'Book',
#   'Copurchased': '0553278339 0933029012 157230376X 157224044X 0829409378',
#   'SalesRank': 421103,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415925398': {'Id': '69',
#   'Title': 'Negotiated Empires: Centers and Peripheries in the New World, 1500-1820',
#   'Categories': 'america studi book subject histor histori historiographi general',
#   'Group': 'Book',
#   'Copurchased': '0333963415 069100840X 0521627249',
#   'SalesRank': 454490,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415223954': {'Id': '70',
#   'Title': 'Geographies of Young People: The Morally Contested Spaces of Identity (Critical Geographies)',
#   'Categories': 'children geographi nonfict studi book social scienc subject sociolog human general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 973410,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '157281196X': {'Id': '72',
#   'Title': 'Power of Flowers: An Archetypal Journey Through Nature',
#   'Categories': 'new religion divin book spiritu age subject tarot entertain card general game',
#   'Group': 'Book',
#   'Copurchased': '1572812575 1879181940 1879181827 1879181894',
#   'SalesRank': 348412,
#   'TotalReviews': 3,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375803394': {'Id': '73',
#   'Title': 'The Perfect Plan (7th Heaven)',
#   'Categories': 'popular religion children famili heaven book christian life subject literatur age place cultur seri peopl seventh general',
#   'Group': 'Book',
#   'Copurchased': '037580336X 0061066249',
#   'SalesRank': 561551,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0113300174': {'Id': '74',
#   'Title': 'Service Delivery (It Infrastructure Library Series)',
#   'Categories': 'com home refer profil busi compani amazon book scienc primer leadership store subject biographi invest offic general manag',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 27507,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786863919': {'Id': '75',
#   'Title': 'Disney A to Z : The Updated Official Encyclopedia (Disney a to Z)',
#   'Categories': 'home refer americana pop cultur book subject collect movi televis garden entertain antiqu art encyclopedia',
#   'Group': 'Book',
#   'Copurchased': '0786885270',
#   'SalesRank': 161879,
#   'TotalReviews': 9,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1581150040': {'Id': '76',
#   'Title': "The Writer's Legal Guide (2nd ed)",
#   'Categories': 'profession technic patent law refer practic write properti book trademark publish subject copyright guid intellectu general authorship',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1151885,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312982178': {'Id': '77',
#   'Title': 'Water Touching Stone',
#   'Categories': 'book subject thriller mysteri general',
#   'Group': 'Book',
#   'Copurchased': '0312978340 1569472424',
#   'SalesRank': 27012,
#   'TotalReviews': 11,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0874850037': {'Id': '78',
#   'Title': 'The Ebony Cookbook: A Date With a Dish',
#   'Categories': 'wine african region book intern subject food u american cook general',
#   'Group': 'Book',
#   'Copurchased': '0874850908 0688100120 0060958138 0966187202 0688162193',
#   'SalesRank': 140480,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0811726371': {'Id': '79',
#   'Title': "Today's Military Wife: Meeting the Challenges of Service Life (Today's Military Wife)",
#   'Categories': 'refer nonfict studi book subject women general',
#   'Group': 'Book',
#   'Copurchased': '1403303193 0962622826 1401086276',
#   'SalesRank': 7437,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1884997015': {'Id': '80',
#   'Title': 'In Quest of God: The Saga of an Extraordinary Pilgrimage',
#   'Categories': 'religion eastern e author memoir book z spiritu subject biographi eknath easwaran general',
#   'Group': 'Book',
#   'Copurchased': '1573227153 0517543052',
#   'SalesRank': 533031,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0140430407': {'Id': '82',
#   'Title': 'Puddnhead Wilson : And, Those Extraordinary Twins (The Penguin English Library)',
#   'Categories': 'th centuri paperback twain author state classic general book z subject literatur mark unit fiction world',
#   'Group': 'Book',
#   'Copurchased': '0140186867 0553211439 0451527569 0553211587 0140390308',
#   'SalesRank': 60668,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '059516630X': {'Id': '83',
#   'Title': 'A Candle for Bobby',
#   'Categories': 'book contemporari subject literatur fiction general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 3272795,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0912500476': {'Id': '85',
#   'Title': 'Amamantar Sencillo y Puro',
#   'Categories': 'babi feed breastfeed video famili book specialti subject toddler store categori music parent',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1246085,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0807205249': {'Id': '86',
#   'Title': 'Junie B. Jones Collection: Books 9-12',
#   'Categories': 'format children tape book literatur fiction general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1525696,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0415157528': {'Id': '87',
#   'Title': 'Colloquial Polish: The Complete Course for Beginners (Colloquial Series (Book Only))',
#   'Categories': 'english refer dictionari thesaurus book languag polish foreign subject instruct general',
#   'Group': 'Book',
#   'Copurchased': '2831571979 0415224373 0781802822 0764110209',
#   'SalesRank': 393166,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '039802278X': {'Id': '88',
#   'Title': 'Normal and Abnormal Development: The Influence of Primitive Reflexes on Motor Development',
#   'Categories': '',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 353149,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0671727737': {'Id': '90',
#   'Title': 'The Eagle Has Landed',
#   'Categories': 'intrigu stori tale spi book subject thriller mysteri',
#   'Group': 'Book',
#   'Copurchased': '0671746693 0425157547 0425138232 042517607X 0425148289',
#   'SalesRank': 841921,
#   'TotalReviews': 46,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1566913810': {'Id': '91',
#   'Title': 'Foghorn Outdoors: New England Hiking 3 Ed: The Complete Guide to More than 380 Hikes',
#   'Categories': 'new com state region amazon book subject store categori england unit travel northeast',
#   'Group': 'Book',
#   'Copurchased': '0897323270 1566914027 0881504548 0762701641',
#   'SalesRank': 333198,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '037575380X': {'Id': '92',
#   'Title': 'Black No More : A Novel (Modern Library (Paperback))',
#   'Categories': 'general stori state classic book contemporari subject literatur short unit fiction world',
#   'Group': 'Book',
#   'Copurchased': '1555530249 0807009199 0393956008 048628512X',
#   'SalesRank': 251469,
#   'TotalReviews': 7,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0965740056': {'Id': '93',
#   'Title': 'BizPricer¿ Business Valuation Manual w/Software',
#   'Categories': 'com home corpor busi small amazon book subject financ entrepreneurship store invest offic general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1485593,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '039572774X': {'Id': '94',
#   'Title': 'The American Heritage Dictionary of Idioms',
#   'Categories': 'idiom english refer dictionari thesaurus book subject slang general',
#   'Group': 'Book',
#   'Copurchased': '006270107X 0844204625 0590381571 0844257796',
#   'SalesRank': 166549,
#   'TotalReviews': 15,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0887402631': {'Id': '95',
#   'Title': 'The Heavy Flak Guns, 1933-1945: 88Mm, 105Mm, 128Mm, 150Mm, and Ballistic Directional Equipment',
#   'Categories': 'book subject scienc histori technolog',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1369585,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0310485002': {'Id': '96',
#   'Title': 'Becoming a Contagious Christian',
#   'Categories': 'discipleship religion live spiritu book christian subject inspir protestant general',
#   'Group': 'Book',
#   'Copurchased': '0310500818 0310250005 0830822763 1576832201 0830819711',
#   'SalesRank': 215846,
#   'TotalReviews': 21,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '042515517X': {'Id': '97',
#   'Title': 'Year of the Tiger',
#   'Categories': 'intrigu stori tale spi book contemporari subject literatur thriller mysteri fiction general',
#   'Group': 'Book',
#   'Copurchased': '0425161021 0425176312 0671725319 0425184250',
#   'SalesRank': 509767,
#   'TotalReviews': 5,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0071402306': {'Id': '99',
#   'Title': "An Employee's Guide to Stock Options",
#   'Categories': 'com technic profession home busi account amazon book subject financ option store invest offic person general',
#   'Group': 'Book',
#   'Copurchased': '076455364X 0966889924 0471394815 0595169252',
#   'SalesRank': 228734,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0787958743': {'Id': '100',
#   'Title': 'Guide to Effective Staff Development in Health Care Organizations : A Systems Approach to Successful Training (J-B AHA Press)',
#   'Categories': 'profession technic medicin book subject econom medic administr polici general',
#   'Group': 'Book',
#   'Copurchased': '1886624089 0875847471 0787955965',
#   'SalesRank': 783690,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0743509315': {'Id': '101',
#   'Title': 'Separation Of Power',
#   'Categories': 'format polit intrigu stori genr tale spi book cd subject literatur thriller suspens mysteri fiction general',
#   'Group': 'Book',
#   'Copurchased': '0671023209 0671047329 0671023187',
#   'SalesRank': 612868,
#   'TotalReviews': 76,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1858685486': {'Id': '102',
#   'Title': 'Mensa Visual Brainteasers',
#   'Categories': 'logic puzzl teaser book subject brain entertain general game',
#   'Group': 'Book',
#   'Copurchased': '0201135493 0970825307',
#   'SalesRank': 576507,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0151803870': {'Id': '103',
#   'Title': 'Selected Essays',
#   'Categories': 'religion eliot e author classic book spiritu z subject literatur fiction essay general',
#   'Group': 'Book',
#   'Copurchased': '0156177358 0811201570 015121185X 0811201511',
#   'SalesRank': 324548,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0820451576': {'Id': '104',
#   'Title': 'Owning Culture: Authorship, Ownership, and Intellectual Property Law (Popular Culture and Everyday Life, Vol. 1)',
#   'Categories': 'profession technic law busi properti book subject intellectu general',
#   'Group': 'Book',
#   'Copurchased': '0814788076 1573928895',
#   'SalesRank': 592661,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1555919332': {'Id': '105',
#   'Title': 'Learning in Overdrive: Designing Curriculum, Instruction, and Assessment from Standards : A Manual for Teachers',
#   'Categories': 'profession technic standard lesson educ nonfict book subject assess financ theori pedagogi plan general',
#   'Group': 'Book',
#   'Copurchased': '0226820319 0871205122 0684836319 013093058X',
#   'SalesRank': 114176,
#   'TotalReviews': 2,
#   'AvgRating': 2.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0821825917': {'Id': '106',
#   'Title': 'Filtrations on the Homology of Algebraic Varieties (Memoirs of the American Mathematical Society, 529)',
#   'Categories': 'book subject scienc mathemat general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1646865,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '038548125X': {'Id': '107',
#   'Title': 'Mothers and Daughters',
#   'Categories': 'camera motherhood marriag nonfict famili book relationship social scienc subject categori parent art sociolog photo photographi essay general',
#   'Group': 'Book',
#   'Copurchased': '156138450X 0762411090 0762411147 0811806197',
#   'SalesRank': 432141,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0838531377': {'Id': '108',
#   'Title': 'General Ophthalmology',
#   'Categories': 'profession technic medicin otolaryngolog specialti book subject surgeri medic ophthalmolog',
#   'Group': 'Book',
#   'Copurchased': '0937404632 0940780518 156053429X 0071375430 0891283463',
#   'SalesRank': 635566,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0471346608': {'Id': '109',
#   'Title': 'Baby Basics : A Guide for New Parents',
#   'Categories': 'music infant develop babi bodi video book toddler parent person health subject store general pregnanc famili specialti women mind childbirth',
#   'Group': 'Book',
#   'Copurchased': '0062731041 0316778001 0764565168 0761121323',
#   'SalesRank': 502928,
#   'TotalReviews': 5,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0684868008': {'Id': '110',
#   'Title': 'Casanova in Bohemia : A Novel',
#   'Categories': 'classic genr fiction memoir book z histor subject literatur compos mozart music biographi entertain peopl amadeus wolfgang',
#   'Group': 'Book',
#   'Copurchased': '031211933X 031213570X 1574231596',
#   'SalesRank': 92775,
#   'TotalReviews': 10,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0736805656': {'Id': '111',
#   'Title': 'The Maine Coon Cat (Learning About Cats)',
#   'Categories': 'cat children anim nonfict book subject pet',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1612259,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1572315938': {'Id': '112',
#   'Title': 'Official Microsoft Image Composer Book',
#   'Categories': 'graphic web site comput commerc general book compos internet html subject applic illustr design develop imag',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 682312,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0736625801': {'Id': '113',
#   'Title': 'Jesus: A Life',
#   'Categories': '',
#   'Group': 'Book',
#   'Copurchased': '0393317609 0800614437 0140144994 0060616628',
#   'SalesRank': 2213377,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0809240394': {'Id': '114',
#   'Title': 'Bowl Like a Pro',
#   'Categories': 'bowl sport book subject individu general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 887935,
#   'TotalReviews': 3,
#   'AvgRating': 2.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0533139317': {'Id': '115',
#   'Title': 'Growing Millionaire Kids',
#   'Categories': 'com home busi amazon book subject store invest offic general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1217413,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0820112518': {'Id': '116',
#   'Title': 'The Life of Benjamin West',
#   'Categories': 'memoir book z benjamin subject biographi art west artist photographi general v',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 3312631,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0380819546': {'Id': '117',
#   'Title': 'Site Unseen : An Emma Fielding Mystery (Emma Fielding Mysteries)',
#   'Categories': 'sleuth book subject thriller mysteri women seri general',
#   'Group': 'Book',
#   'Copurchased': '0380819554',
#   'SalesRank': 38915,
#   'TotalReviews': 6,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0590464272': {'Id': '118',
#   'Title': 'The Magic School Bus At The Waterworks : (autobus Magico Viaja Por...) (Magic School Bus)',
#   'Categories': 'format children school action juvenil infantil work año libro español natur book reader scienc literatur joanna earli bruce author pictur z age subject fiction degen en cole ficción adventur illustr magic seri bus c',
#   'Group': 'Book',
#   'Copurchased': '0590464299 0590006371 059046342X',
#   'SalesRank': 654728,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0849943221': {'Id': '119',
#   'Title': 'Black Friday (Soul Survivor Series, Bk. 4)',
#   'Categories': 'religion intrigu paperback stori author tim spi tale l lahay z book subject spiritu thriller mysteri fiction general',
#   'Group': 'Book',
#   'Copurchased': '0849943205 0849942993',
#   'SalesRank': 762209,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0140445684': {'Id': '120',
#   'Title': 'Capital : A Critique of Political Economy (Penguin Classics)',
#   'Categories': 'ideolog polit nonfict book social subject radic communism philosophi thought general',
#   'Group': 'Book',
#   'Copurchased': '0451527100 0140445757 0879757051 0553585975 1573921394',
#   'SalesRank': 17693,
#   'TotalReviews': 40,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0688060676': {'Id': '121',
#   'Title': 'Ten Black Dots',
#   'Categories': 'babi children author basic crew book age concept z specialti subject store illustr music donald general c',
#   'Group': 'Book',
#   'Copurchased': '0140554955 0671792474 0440404959 0688147402 0689808925',
#   'SalesRank': 144348,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '059047913X': {'Id': '123',
#   'Title': 'You Can Name 100 Dinosaurs!',
#   'Categories': 'babi children nonfict anim book subject dinosaur general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 651510,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '076453243X': {'Id': '125',
#   'Title': 'Adobe® InDesign¿ Bible',
#   'Categories': 'graphic web comput desktop adob book publish internet html subject illustr design develop indesign general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 405530,
#   'TotalReviews': 5,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0395530377': {'Id': '126',
#   'Title': 'Houghton Mifflin Mathematics: Practice Activity Level 7',
#   'Categories': 'children math book technolog scienc work subject natur mathemat teen general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1804602,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0878301534': {'Id': '127',
#   'Title': 'Ballroom Dancing',
#   'Categories': 'popular refer book danc ballroom subject perform art photographi general',
#   'Group': 'Book',
#   'Copurchased': '0028643453 0943955777 0965442330',
#   'SalesRank': 36535,
#   'TotalReviews': 5,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312871880': {'Id': '128',
#   'Title': 'Irish Stew!',
#   'Categories': 'author sleuth greeley book z literari literatur g subject thriller mysteri women andrew seri fiction general',
#   'Group': 'Book',
#   'Copurchased': '0812576063 0812590236 0812577701 0812590244 0812550773',
#   'SalesRank': 368790,
#   'TotalReviews': 5,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1579473024': {'Id': '129',
#   'Title': 'Cpt 2003: Current Procedural Terminology (Cpt / Current Procedural Terminology (Standard Edition))',
#   'Categories': 'profession medicin technic reimburs refer practic book scienc record subject econom medic administr polici histori general manag',
#   'Group': 'Book',
#   'Copurchased': '1579473350 1570662592',
#   'SalesRank': 256979,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0767905288': {'Id': '130',
#   'Title': "The O'Reilly Factor: The Good, the Bad, and the Completely Ridiculous in American Life",
#   'Categories': 'polit nonfict practic book subject u parti general',
#   'Group': 'Book',
#   'Copurchased': '0767908481 0060514558',
#   'SalesRank': 29460,
#   'TotalReviews': 375,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '078795893X': {'Id': '131',
#   'Title': 'The 2R Manager: When to Relate, When to Require, and How to Do Both Effectively',
#   'Categories': 'com career home busi small amazon book subject leadership entrepreneurship store invest offic general manag',
#   'Group': 'Book',
#   'Copurchased': '0743212347 0684834316 0875849369',
#   'SalesRank': 122152,
#   'TotalReviews': 3,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0743504097': {'Id': '132',
#   'Title': 'Iyanla Live! : Back to Basics (Iyanla Live!)',
#   'Categories': 'format psycholog philosophi transform bodi religion book person vanzant v author health help z subject motiv general self iyanla tape spiritu growth inspir mind',
#   'Group': 'Book',
#   'Copurchased': '0743507541 0743504089 0743500393 0743506359 0743507924',
#   'SalesRank': 868001,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0877936528': {'Id': '134',
#   'Title': 'Growing Teen Disciples: Strategies for Really Effective Youth Ministry',
#   'Categories': 'religion youth book christian spiritu subject clergi ministri',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1646474,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0609608363': {'Id': '135',
#   'Title': 'Wondrous Contrivances : Technology at the Threshold',
#   'Categories': 'america state book scienc subject unit technolog mathemat histori general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 408802,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0452011604': {'Id': '136',
#   'Title': 'Understanding Islam: An Introduction to the Muslim World, Third Revised and Updated Edition',
#   'Categories': 'religion spiritu book subject general islam',
#   'Group': 'Book',
#   'Copurchased': '081296618X 0140175962 0140445587 0195130766',
#   'SalesRank': 90195,
#   'TotalReviews': 14,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0781433525': {'Id': '137',
#   'Title': 'Apples of Gold: A Six-Week Nurturing Program for Women',
#   'Categories': 'religion live general spiritu book christian organ subject issu inspir church women clergi institut',
#   'Group': 'Book',
#   'Copurchased': '0781438098 0781438055 1885904177 0891077197',
#   'SalesRank': 129355,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0824518659': {'Id': '139',
#   'Title': 'The Sacred Impulse',
#   'Categories': 'ecolog religion spiritu environ christian book subject inspir catholic natur general outdoor',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 846457,
#   'TotalReviews': 1,
#   'AvgRating': 3.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786710772': {'Id': '140',
#   'Title': 'Power & Greed: A Short History of the World',
#   'Categories': 'general book specialti subject store jp unknown histori world',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 788014,
#   'TotalReviews': 5,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1886110867': {'Id': '141',
#   'Title': 'Coach K: Building the Duke Dynasty : Building the Duke Dynasty',
#   'Categories': 'colleg sport book subject univers biographi basketbal general',
#   'Group': 'Book',
#   'Copurchased': '0446530603 0446676780 0822313189',
#   'SalesRank': 401565,
#   'TotalReviews': 10,
#   'AvgRating': 2.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0590108859': {'Id': '142',
#   'Title': 'Chemical Chaos (Horrible Science)',
#   'Categories': 'children book age scienc work subject natur chemistri general',
#   'Group': 'Book',
#   'Copurchased': '0439043638 0590138596 0590216872',
#   'SalesRank': 280529,
#   'TotalReviews': 3,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '080784991X': {'Id': '143',
#   'Title': 'Ghosts from the Coast',
#   'Categories': 'religion occult book reader scienc literatur social folklor horror state subject collect mysteri ghost fiction general world supernatur nonfict spiritu unexplain mytholog unit',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1079230,
#   'TotalReviews': 2,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0195044193': {'Id': '144',
#   'Title': 'The Paradox of Change: American Women in the 20th Century',
#   'Categories': 'th centuri america state nonfict studi book subject women unit histori general',
#   'Group': 'Book',
#   'Copurchased': '0465041930 0394745361 025206318X',
#   'SalesRank': 596032,
#   'TotalReviews': 0,
# ...
#  '0762708085': {'Id': '1348',
#   'Title': 'Fun with the Family in Michigan: Hundreds of Ideas for Day Trips with the Kids',
#   'Categories': 'com midwest state region michigan famili amazon book specialti subject store categori unit travel general',
#   'Group': 'Book',
#   'Copurchased': '1560445181 0814328296 0786853026',
#   'SalesRank': 692681,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0786868821': {'Id': '1349',
#   'Title': 'Cad: Confessions of a Toxic Bachelor',
#   'Categories': 'graphic profession specif group humor strip memoir book subject novel academ journalist biographi comic women entertain general',
#   'Group': 'Book',
#   'Copurchased': '0306812274 0375726497',
#   'SalesRank': 247366,
#   'TotalReviews': 44,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0826314384': {'Id': '1351',
#   'Title': 'Tierra Amarilla: Stories of New Mexico : Cuentos De Nuevo Mexico (Paso Por Aqui)',
#   'Categories': 'world stori state book spanish subject literatur short thriller mysteri british unit fiction general',
#   'Group': 'Book',
#   'Copurchased': '0884121054',
#   'SalesRank': 920020,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0811201511': {'Id': '1352',
#   'Title': 'ABC of Reading',
#   'Categories': 'th centuri general author state poetri p book z subject singl literatur unit ezra fiction pound world',
#   'Group': 'Book',
#   'Copurchased': '0811201570 0811213269 0811201562 0811201627 0520024273',
#   'SalesRank': 202498,
#   'TotalReviews': 14,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0893343218': {'Id': '1353',
#   'Title': 'Teachers Guide to Community Organization: Strategies for Parent, Teacher and Community Groups to Improve the Schools',
#   'Categories': 'russia educ specif group nonfict memoir book subject biographi pedagogi women polici histori general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1898676,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '030680736X': {'Id': '1354',
#   'Title': 'Dr. Seuss & Mr. Geisel: A Biography',
#   'Categories': 'popular children author famili book memoir subject literatur guid biographi parent art charact seuss general dr',
#   'Group': 'Book',
#   'Copurchased': '0876146272 0679883568 0679434488',
#   'SalesRank': 97073,
#   'TotalReviews': 9,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0674008340': {'Id': '1355',
#   'Title': 'Black Rice: The African Origins of Rice Cultivation in the Americas',
#   'Categories': 'african group nonfict studi book social subject special scienc american sociolog general',
#   'Group': 'Book',
#   'Copurchased': '0140092331',
#   'SalesRank': 282005,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0742512967': {'Id': '1356',
#   'Title': "American Heat: Ethical Problems With the United States' Response to Global Warming (Studies in Social, Political, and Legal Philosophy)",
#   'Categories': 'polit nonfict modern environ public book natur subject conserv u philosophi govern polici general outdoor',
#   'Group': 'Book',
#   'Copurchased': '1583224777 0871566222 089608650X 0786884401',
#   'SalesRank': 846687,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1558746609': {'Id': '1357',
#   'Title': "Chicken Soup for the Golfer's Soul: Stories of Insight, Inspiration and Laughter on the Links (Chicken Soup Series)",
#   'Categories': 'format sport jack bodi religion canfield book golf author health help z subject general self spiritu cd inspir mind c',
#   'Group': 'Book',
#   'Copurchased': '1558749829 155874875X 1558744606 1558749659',
#   'SalesRank': 476325,
#   'TotalReviews': 12,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553214985': {'Id': '1358',
#   'Title': 'A Country Doctor (Bantam Classic)',
#   'Categories': 'classic book subject literatur fiction general',
#   'Group': 'Book',
#   'Copurchased': '0451527577 0395345308 0486408841',
#   'SalesRank': 437457,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '4333014786': {'Id': '1360',
#   'Title': 'Zen Seeds: Reflections of a Female Priest',
#   'Categories': 'religion nonfict book spiritu buddhism subject philosophi general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 512876,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0399146261': {'Id': '1361',
#   'Title': 'Three Complete Novels: Cold Fire, Hideaway, Key to Midnight',
#   'Categories': 'horror dean author state book z k subject koontz unit general',
#   'Group': 'Book',
#   'Copurchased': '0517064871 0517073692 0970998716',
#   'SalesRank': 157418,
#   'TotalReviews': 1,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0306809389': {'Id': '1365',
#   'Title': 'The Duel for France, 1944: The Men and Battles That Changed the Fate of Europe',
#   'Categories': 'world ii war europ western book militari germani subject franc histori general',
#   'Group': 'Book',
#   'Copurchased': '0760311668',
#   'SalesRank': 575583,
#   'TotalReviews': 2,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0781724716': {'Id': '1367',
#   'Title': 'Child and Adolescent Clinical Psychopharmacology',
#   'Categories': 'medicin bodi counsel health pediatr psycholog specialti book subject psychopharmacolog mind general',
#   'Group': 'Book',
#   'Copurchased': '0521655420 088048330X 0781724694',
#   'SalesRank': 191671,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0803949677': {'Id': '1368',
#   'Title': 'The Power of Silence: Social and Pragmatic Perspectives (Language and Language Behavior)',
#   'Categories': 'general refer nonfict book languag communic social subject scienc sociolog word',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 467756,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0822525771': {'Id': '1369',
#   'Title': "David's Story: A Book About Surgery (Meeting the Challenge)",
#   'Categories': 'children book age subject general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1848183,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553214039': {'Id': '1370',
#   'Title': 'The Swiss Family Robinson (Bantam Classics)',
#   'Categories': 'classic genr action book subject literatur adventur fiction general',
#   'Group': 'Book',
#   'Copurchased': '0451527046 0486404277 0812550927 059043053X 0140390839',
#   'SalesRank': 1086094,
#   'TotalReviews': 52,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0553298046': {'Id': '1371',
#   'Title': 'Specter of the Past (Star Wars: The Hand of Thrawn, Book One)',
#   'Categories': 'fantasi war book scienc subject star seri fiction general media',
#   'Group': 'Book',
#   'Copurchased': '0553564927 0553560719 0553296124 0553574140',
#   'SalesRank': 18558,
#   'TotalReviews': 221,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0471625469': {'Id': '1372',
#   'Title': 'An Introduction to the Theory of Numbers',
#   'Categories': 'profession technic pure number book scienc subject theori mathemat',
#   'Group': 'Book',
#   'Copurchased': '0883856190 0198531710 048668735X 038797329X',
#   'SalesRank': 263175,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0312063261': {'Id': '1373',
#   'Title': "Dancing on Tisha B'av",
#   'Categories': 'book subject literatur gay lesbian fiction',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 353629,
#   'TotalReviews': 2,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '8817125539': {'Id': '1374',
#   'Title': 'An Italian in America',
#   'Categories': 'com itali europ amazon memoir book subject store categori biographi travel general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 238275,
#   'TotalReviews': 14,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0531164659': {'Id': '1375',
#   'Title': 'High School Hazing: When Rites Become Wrongs (Single Title: Teen)',
#   'Categories': 'bodi children health book social scienc subject place mind peopl teen general',
#   'Group': 'Book',
#   'Copurchased': '025321498X',
#   'SalesRank': 431993,
#   'TotalReviews': 2,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1576751414': {'Id': '1376',
#   'Title': 'Be Your Own Brand: A Breakthrough Formula for Standing Out from the Crowd',
#   'Categories': 'psycholog life transform market secret manag bodi busi book biographi sale mind offic person counsel home success health help subject primer store invest general self com amazon leadership appli advertis',
#   'Group': 'Book',
#   'Copurchased': '0345423593 0967450659 0967450616 0767904923 0375407723',
#   'SalesRank': 141178,
#   'TotalReviews': 9,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0619016884': {'Id': '1377',
#   'Title': '70-220: MCSE Guide to Designing Microsoft Windows 2000 Security',
#   'Categories': 'window project system microsoft manag busi book publish cours offic mcse home internet exam subject store central oper general certif com secur comput amazon os digit cultur technolog',
#   'Group': 'Book',
#   'Copurchased': '0619016930 0619016892 078212898X',
#   'SalesRank': 148463,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0740725300': {'Id': '1378',
#   'Title': 'Traveling Light 2003 Block Calendar: Releasing the Burdens You Were Never Intended to Bear; The',
#   'Categories': 'format religion author lucado spiritu l pop z accessori book subject note max cultur card general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 745630,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0375503366': {'Id': '1379',
#   'Title': 'The Requiem Shark : A Novel',
#   'Categories': 'genr book histor contemporari subject literatur adventur fiction general sea',
#   'Group': 'Book',
#   'Copurchased': '0375759395 0805066152',
#   'SalesRank': 816290,
#   'TotalReviews': 23,
#   'AvgRating': 4.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0914732218': {'Id': '1380',
#   'Title': 'AGHORA, At the Left Hand of God (Aghora)',
#   'Categories': 'religion occult spiritu book buddhism subject general',
#   'Group': 'Book',
#   'Copurchased': '0914732315 0914732374 0892540486 1883725046 0965620832',
#   'SalesRank': 62274,
#   'TotalReviews': 21,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '9812348174': {'Id': '1381',
#   'Title': 'Insight Compact Guide Ireland (Insight Compact Guides)',
#   'Categories': 'com pocket europ amazon book insight subject store categori seri guid travel guidebook ireland general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1175363,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0632057718': {'Id': '1382',
#   'Title': "Architects' Data",
#   'Categories': 'profession technic architectur refer general style book subject build type',
#   'Group': 'Book',
#   'Copurchased': '0823072711 0471348163',
#   'SalesRank': 365164,
#   'TotalReviews': 3,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1876175087': {'Id': '1384',
#   'Title': "Che in Africa: Che Guevara's Congo Diary",
#   'Categories': 'africa guevara indi academ democrat peopl profession cuba congo book militari biographi republ memoir z subject g histor general polit america che spi notabl leader west caribbean histori',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 836852,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1870775724': {'Id': '1388',
#   'Title': 'Creating a Music Website',
#   'Categories': 'web site comput commerc mixer midi book etc composit internet subject theori perform music entertain develop design general',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1046034,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0813521505': {'Id': '1389',
#   'Title': "Irrationality: Why We Don't Think Straight!",
#   'Categories': 'profession bodi technic counsel health psycholog book behavior scienc subject mind general cognit',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 739364,
#   'TotalReviews': 4,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '087840273X': {'Id': '1391',
#   'Title': 'Alif Baa: Introduction to Arabic Letters and Sounds',
#   'Categories': 'linguist general refer book languag foreign arab subject instruct word',
#   'Group': 'Book',
#   'Copurchased': '0878402918 0879500034',
#   'SalesRank': 23006,
#   'TotalReviews': 24,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0395742129': {'Id': '1393',
#   'Title': 'A Turkey for Thanksgiving',
#   'Categories': 'children festiv author fiction eve book age thanksgiv z subject place bunt illustr holiday b peopl general',
#   'Group': 'Book',
#   'Copurchased': '0448425297 0448422867 0679852921 0064432041 0531059057',
#   'SalesRank': 273599,
#   'TotalReviews': 7,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0452284015': {'Id': '1394',
#   'Title': 'The Darwin Awards II : Unnatural Selection',
#   'Categories': 'humor book subject entertain essay general',
#   'Group': 'Book',
#   'Copurchased': '0385483414 0740710028 0385419287',
#   'SalesRank': 26591,
#   'TotalReviews': 31,
#   'AvgRating': 3.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0743407083': {'Id': '1395',
#   'Title': 'Grand Avenue',
#   'Categories': 'romanc author book z contemporari subject field literatur joy f fiction general',
#   'Group': 'Book',
#   'Copurchased': '0743407067 0380711532 0451155068 0380711524',
#   'SalesRank': 177689,
#   'TotalReviews': 71,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0944386237': {'Id': '1396',
#   'Title': 'The Bible Interpreted in Dream Symbols',
#   'Categories': 'dream psycholog bodi religion occult studi book controversi counsel health religi subject knowledg mysteri mental general spiritu unexplain mind',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 1598633,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1573801534': {'Id': '1397',
#   'Title': "Insiders' Guide to Yellowstone and Grand Teton",
#   'Categories': 'mountain campground yellowston region book insid travel state subject park store categori wyom general com amazon lodg food west unit seri guidebook',
#   'Group': 'Book',
#   'Copurchased': '',
#   'SalesRank': 944279,
#   'TotalReviews': 1,
#   'AvgRating': 5.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '0520203569': {'Id': '1401',
#   'Title': 'Early Modern Japan',
#   'Categories': 'book subject japan asia histori',
#   'Group': 'Book',
#   'Copurchased': '0520218124 0824818504 0860084906 0816512566 0804801843',
#   'SalesRank': 587569,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1878610473': {'Id': '1403',
#   'Title': 'Working in the Dark: Reflections of a Poet of the Barrio',
#   'Categories': 'author book memoir subject literatur biographi art general',
#   'Group': 'Book',
#   'Copurchased': '0802139086 0811211029 0802139477 0802138144 0811210324',
#   'SalesRank': 484620,
#   'TotalReviews': 4,
#   'AvgRating': 4.5,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  '1864500069': {'Id': '1405',
#   'Title': 'Loney Planet Chicago City Map (City Maps Series)',
#   'Categories': 'com midwest illinoi refer region state amazon book subject map store categori atlas unit travel chicago',
#   'Group': 'Book',
#   'Copurchased': '0935039244 0935039546',
#   'SalesRank': 554729,
#   'TotalReviews': 0,
#   'AvgRating': 0.0,
#   'DegreeCentrality': 0,
#   'ClusteringCoeff': 0.0},
#  ...}

# %%
amazonBooks['059035342X']
# Out:
# {'Id': '148185',
#  'Title': "Harry Potter and the Sorcerer's Stone (Book 1)",
#  'Categories': 'fantasi children rowl paperback r book j scienc literatur horror author harri age z subject mysteri fiction general potter humor k adventur illustr magic seri',
#  'Group': 'Book',
#  'Copurchased': '0439064864 0439136350 0439139600 043935806X',
#  'SalesRank': 746,
#  'TotalReviews': 5034,
#  'AvgRating': 5.0,
#  'DegreeCentrality': 0,
#  'ClusteringCoeff': 0.0}

# %% [markdown]
# Use the copurchase data in Amazon books dictionary to create the copurchase graph structure as follows:
# - NODES: are the ASINs
# - EDGES: exist between two Nodes if the two ASINs were co-purchased
# - EDGE WEIGHT: it is based on category similarity
# - SIMILARITY: it is a measure between any two ASINs that were co-purchased and it can be calculated as the number of words that are common between categories of connected Nodes divided by the total number of words in both categories of connected nodes. The similarity range goes from 0 (most dissimilar) to 1 (most similar).

# %% [markdown]
# # Create a product copurchase graph for analysis based on Jaccard Similarity of common words in the Categories column

# %%
## The graph nodes are product ASINs, the graph edge exists
## if two products were copurchased with edge weight being
## a measure of category similarity between ASINs

copurchaseGraph = networkx.Graph()
for asin, metadata in amazonBooks.items():
    copurchaseGraph.add_node(asin)
    for a in metadata ['Copurchased'].split():
        copurchaseGraph.add_node(a.strip())
        similarity= 0
        n1= set((amazonBooks[asin]['Categories']).split())
        n2= set ((amazonBooks[a]['Categories']).split())
        n1In2 = n1 & n2 #intersection: number of words that are common between categories of connected nodes
        n1Un2 = n1 | n2 #union: total number of words in both categories of connected nodes
        if (len(n1Un2)) > 0:
            similarity = round (len(n1In2)/len(n1Un2), 2)
        copurchaseGraph.add_edge(asin, a.strip(), weight = similarity)

# %% [markdown]
# ## Add the graph-related measures Degree centrality and Clustering coefficient for each ASIN node and add it to amazonBooks metadata.

# %%
# Get degree centrality and clustering coefficients
## of each node and add it to amazonBooks metadata.

dc = networkx.degree(copurchaseGraph)
for asin in networkx.nodes(copurchaseGraph):
    metadata = amazonBooks[asin]
    metadata['DegreeCentrality'] = int(dc[asin])
    ego = networkx.ego_graph(copurchaseGraph, asin, radius = 1)
    metadata['ClusteringCoeff'] = round(networkx.average_clustering(ego), 2)
    amazonBooks[asin] = metadata

# %% [markdown]
# ## Write out Amazon books data to the amazon-books.txt file and the copurchase graph data to the amazon-books-copurchase.edgelist file.

# %%
# Write amazonBooks data to file
df1 = open('./amazon-books.txt', 'w', encoding = 'utf-8', errors = 'ignore')
df1.write('Id\t' + 'ASIN\t' + 'Title\t'+
         'Categories\t' + 'Group\t' + 'Copurchased\t'+
         'SalesRank\t' + 'TotalReviews\t' + 'AvgRating\t'+
         'DegreeCentrality\t' + 'ClusteringCoeff\n')
for asin, metadata in amazonBooks.items():
    df1.write(metadata['Id'] + '\t' +
              asin + '\t' +
              metadata['Title'] + '\t' +
              metadata['Categories'] + '\t' +
              metadata['Group'] + '\t' +
              metadata['Copurchased'] +'\t' +
              str(metadata['SalesRank']) + '\t' +
              str(metadata['TotalReviews']) + '\t' +
              str(metadata['AvgRating']) + '\t' +
              str(metadata['DegreeCentrality']) + '\t' +
              str(metadata['ClusteringCoeff']) + '\n')
df1.close()

# Write copurchaseGraph to file
df1 = open('amazon-books-copurchase.edgelist', 'wb')
networkx.write_weighted_edgelist(copurchaseGraph, df1)
df1.close()

# %% [markdown]
# ## Reading the text file

# %%
Books_File = open('amazon-books.txt', 'r', encoding = 'utf-8', errors = 'ignore')
Books = {}
Books_File.readline()
for line in Books_File:
    cell = line.split("\t")
    MetaData = {}
    MetaData['Id'] = cell[0].strip()
    ASIN = cell[1].strip()
    MetaData['Title'] = cell[2].strip()
    MetaData['Categories'] = cell[3].strip()
    MetaData['Group'] = cell[4].strip()
    MetaData['Copurchased'] = cell[5].strip()
    MetaData['SalesRank'] = int(cell[6].strip())
    MetaData['TotalReviews'] = int(cell[7].strip())
    MetaData['AvgRating'] = float(cell[8].strip())
    MetaData['DegreeCentrality'] = int(cell[9].strip())
    MetaData['ClusteringCoeff'] = float(cell[10].strip())
    Books[ASIN] = MetaData
Books_File.close()

# %%
Books_File = open("amazon-books-copurchase.edgelist", "rb")
Copurchase_Graph = networkx.read_weighted_edgelist(Books_File)
Books_File.close()

# %% [markdown]
# ## Giving Book ASIN id as input for recommending books

# %%
print("Looking for Recommendations for Customer Purchasing this Book: ")
print("---------------------------------------------------------------")
# Purchased_ASIN = '0805047905'
Purchased_ASIN = input("Enter the ASIN of the book you purchased: ")
print("ASIN = ", Purchased_ASIN)
print("Title = ", Books[Purchased_ASIN]['Title'])
print("SalesRank = ", Books[Purchased_ASIN]['SalesRank'])
print("TotalReviews = ", Books[Purchased_ASIN]['TotalReviews'])
print("AvgRating = ", Books[Purchased_ASIN]['AvgRating'])
print("DegreeCentrality = ", Books[Purchased_ASIN]['DegreeCentrality'])
print("ClusteringCoeff = ", Books[Purchased_ASIN]['ClusteringCoeff'])
# Out:
# Looking for Recommendations for Customer Purchasing this Book:
# ---------------------------------------------------------------
# Enter the ASIN of the book you purchased: 059035342X
# ASIN =  059035342X
# Title =  Harry Potter and the Sorcerer's Stone (Book 1)
# SalesRank =  746
# TotalReviews =  5034
# AvgRating =  5.0
# DegreeCentrality =  4
# ClusteringCoeff =  1.0

# %% [markdown]
# ## Visualize the Ego graph for the ASIN Product Query

# %%
n = Purchased_ASIN
ego = networkx.ego_graph(Copurchase_Graph, n, radius = 1)
Purchased_ASIN_Ego_Graph = networkx.Graph(ego)
plt.figure(figsize = (10, 10))
pos = networkx.spring_layout(Purchased_ASIN_Ego_Graph)
plt.show(networkx.draw(Purchased_ASIN_Ego_Graph, pos, node_color = 'blue', node_size = 500, with_labels = True))

# %% [markdown]
# ## Finding the books with a similarity measure based on threshold value

# %%
threshold = 0.5 # finding the nodes having similarity measure based on category above the threshold value
Purchased_ASIN_Ego_Trim_Graph = networkx.Graph()
for f, t, e in Purchased_ASIN_Ego_Graph.edges(data = True):
    if e['weight'] >= threshold:
        Purchased_ASIN_Ego_Trim_Graph.add_edge(f, t)

# %% [markdown]
# ## View the purchased ASINs

# %%
Purchased_ASIN_Neighbors = Purchased_ASIN_Ego_Trim_Graph.neighbors(Purchased_ASIN)

# %%
ASIN_Meta = []
for asin in Purchased_ASIN_Neighbors:
    ASIN = asin
    Title = amazonBooks[ASIN]['Title']
    SalesRank = amazonBooks[ASIN]['SalesRank']
    TotalReviews = amazonBooks[ASIN]['TotalReviews']
    AvgRating = amazonBooks[ASIN]['AvgRating']
    DegreeCentrality = amazonBooks[ASIN]['DegreeCentrality']
    ASIN_Meta.append((ASIN, Title, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff))

# %% [markdown]
# ## Show Top 5 recommendations

# %%
Top5_ByAbgRating_ThenByTotalReviews = sorted(ASIN_Meta, key = lambda x: (x[4], x[3]), reverse = True)[:5]

# %%
print()
print("Top 5 Recommendations By AvgRating Then By TotalReviews for Users Purchased The Book: ")
print("--------------------------------------------------------------------------------------")
print('ASIN\t', 'Title\t', 'SalesRank\t', 'TotalReviews\t', 'AvgRating\t', 'DegreeCentrality\t', 'ClusteringCoeff')
for asin in Top5_ByAbgRating_ThenByTotalReviews:
    print(asin)

print()
# Out:
# Top 5 Recommendations By AvgRating Then By TotalReviews for Users Purchased The Book:
# --------------------------------------------------------------------------------------
# ASIN	 Title	 SalesRank	 TotalReviews	 AvgRating	 DegreeCentrality	 ClusteringCoeff
# ('0439139600', 'Harry Potter and the Goblet of Fire (Book 4)', 404, 4924, 5.0, 24, 0.0)
# ('0439064864', 'Harry Potter and the Chamber of Secrets (Book 2)', 445, 2422, 5.0, 57, 0.0)
# ('0439136350', 'Harry Potter and the Prisoner of Azkaban (Book 3)', 356, 2396, 5.0, 39, 0.0)
# ('043935806X', 'Harry Potter and the Order of the Phoenix (Book 5)', 110, 5545, 4.5, 46, 0.0)
